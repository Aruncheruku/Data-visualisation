# %% [markdown]
# # Data visualization
# # NAME: Cheruku Arun Kumar
# # ID: 24072073
# # Title:Climate and Crops in 2024

# %%
# importing all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv("climate_change_impact_on_agriculture_2024.csv")

# %%
dataset # print data
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
dataset.head() # show top 5 data
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...

# %%
#show last 5 rows dataset
dataset.tail()
# Out:
#       Year    Country              Region Crop_Type  Average_Temperature_C  \
# 9995  2022     France  Nouvelle-Aquitaine    Cotton                  30.48
# 9996  1999  Australia          Queensland  Soybeans                   9.53
# 9997  2000  Argentina           Patagonia    Coffee                  31.92
# 9998  1996     Brazil           Southeast  Soybeans                  13.95
# 9999  2015      China               South      Corn                  11.78
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 9995                  685.93             17.64                 3.033
# 9996                 2560.38             10.68                 2.560
# 9997                  357.76             26.01                 1.161
# 9998                 1549.52             17.31                 3.348
# 9999                 1676.25              5.34                 3.710
#
#       Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# ...

# %%
# calculate mean, median, std, min, max..
dataset.describe()
# Out:
#                Year  Average_Temperature_C  Total_Precipitation_mm  \
# count  10000.000000           10000.000000            10000.000000
# mean    2007.088700              15.241299             1611.663834
# std       10.084245              11.466955              805.016815
# min     1990.000000              -4.990000              200.150000
# 25%     1999.000000               5.430000              925.697500
# 50%     2007.000000              15.175000             1611.160000
# 75%     2016.000000              25.340000             2306.997500
# max     2024.000000              35.000000             2999.670000
#
#        CO2_Emissions_MT  Crop_Yield_MT_per_HA  Extreme_Weather_Events  \
# count      10000.000000          10000.000000            10000.000000
# mean          15.246608              2.240017                4.980900
# std            8.589423              0.998342                3.165808
# min            0.500000              0.450000                0.000000
# ...

# %% [markdown]
# # Plotting Different types of plots on the climate.

# %% [markdown]
# # 1.Line Plot (Avg Temperature vs Year)

# %%
# Plot 1: Line plot Avg Agricultural Temperature Over Time.
plt.figure(figsize=(10, 6))
avg_temp = dataset.groupby("Year")["Average_Temperature_C"].mean().reset_index()
sns.lineplot(data=avg_temp, x="Year", y="Average_Temperature_C", marker="o", linewidth=2.5, color="orange",markerfacecolor="black")
plt.title("Average Agricultural Temperature Over Time", fontsize=14,fontweight="bold")
plt.ylabel("Avg Temperature (°C)",fontweight="bold")
plt.xlabel("Year",fontweight="bold")
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7) 
plt.legend("Year vs Average_Temperature_C",loc = "upper left")
plt.savefig("Average Agricultural Temperature Over Time.png",dpi = 300)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2.Box Plot(Economic Impact by Adaptation Strategy)

# %%
# Plot 2: Economic Impact by Adaptation Strategy
plt.figure(figsize=(10, 8))
sns.boxplot(
    data=dataset,
    x="Adaptation_Strategies",
    y="Economic_Impact_Million_USD",
    hue="Adaptation_Strategies",   
    palette="muted",
    legend=False                         
)
plt.title("Economic Impact Across Adaptation Strategies", fontsize=12,fontweight="bold")
plt.xlabel("Adaptation Strategy",fontweight="bold")
plt.ylabel("Economic Impact (Million USD)",fontweight="bold")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Economic Impact Across Adaptation Strategies.png",dpi = 300)
plt.show()

# %% [markdown]
# # 3. Heat Map

# %%
# Plot 3: Correlation Heatmap of Indicators
plt.figure(figsize=(10, 8))
corr_cols = ["Average_Temperature_C", "Total_Precipitation_mm", "CO2_Emissions_MT",
             "Crop_Yield_MT_per_HA", "Extreme_Weather_Events", "Irrigation_Access_%",
             "Pesticide_Use_KG_per_HA", "Fertilizer_Use_KG_per_HA", "Soil_Health_Index",
             "Economic_Impact_Million_USD"]
corr_matrix = dataset[corr_cols].corr().round(2)
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5, square=True, cbar_kws={"shrink": 0.8})
plt.title("Correlation Heatmap of Climate and Agriculture Indicators", fontsize=16,fontweight="bold")

plt.tight_layout()
plt.savefig("Correlation Heatmap of Climate and Agriculture Indicators.png")
plt.show()

# %% [markdown]
# # 4.Bar Chart

# %%
# plot - 4 :Count of Crop Types grouped by Adaptation Strategy
crop_counts = df.groupby(["Adaptation_Strategies", "Crop_Type"]).size().unstack().fillna(0)

# Plotting the stacked bar chart
crop_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='Set2')

plt.title("Distribution of Crop Types by Adaptation Strategy", fontsize=16,fontweight="bold")
plt.xlabel("Adaptation Strategy",fontweight="bold")
plt.ylabel("Number of Records",fontweight="bold")
plt.legend(title="Crop Type", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.grid(axis='y')
plt.savefig("Distribution of Crop Types by Adaptation Strategy.png")
plt.show()
